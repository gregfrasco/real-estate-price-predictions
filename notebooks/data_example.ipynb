# %%
from utils import get_data

# %%
df = get_data('../data')
df.head(20)
# Out:
#         MLSNUM STATUS LISTPRICE SOLDPRICE    LISTDATE SOLDDATE  EXPIREDDATE  \
# 0   72115048.0    ACT    230000       NaN    2/1/2017      NaN          NaN
# 1   72279074.0    ACT    295500       NaN    2/7/2018      NaN          NaN
# 2   72283298.0    NEW    299000       NaN   2/19/2018      NaN          NaN
# 3   72226474.0    ACT    349000       NaN   9/11/2017      NaN          NaN
# 4   72281946.0    ACT    350000       NaN   2/15/2018      NaN          NaN
# 5   72220564.0    ACT    370000       NaN   8/30/2017      NaN          NaN
# 6   72248924.0    ACT    379000       NaN  10/27/2017      NaN          NaN
# 7   72283112.0    NEW    379000       NaN   2/19/2018      NaN          NaN
# 8   72283083.0    NEW    380000       NaN   2/19/2018      NaN          NaN
# 9   72267208.0    ACT    399000       NaN    1/2/2018      NaN          NaN
# 10  72280995.0    ACT    399900       NaN   2/12/2018      NaN          NaN
# ...

# %%
for col in df.columns: 
    print(col)
# Out:
# MLSNUM
# STATUS
# LISTPRICE
# SOLDPRICE
# LISTDATE
# SOLDDATE
# EXPIREDDATE
# DOM
# DTO
# ADDRESS
# CITY
# STATE
# ZIP
# AREA
# BEDS
# BATHS
# SQFT
# AGE
# LOTSIZE
# AGENTNAME
# OFFICENAME
# OFFICEPHONE
# SHOWINGINSTRUCTIONS
# REMARKS
# STYLE
# LEVEL
# GARAGE
# HEATING
# COOLING
# ELEMENTARYSCHOOL
# JUNIORHIGHSCHOOL
# HIGHSCHOOL
# OTHERFEATURES
# PROPTYPE
# STREETNAME
# HOUSENUM1
# HOUSENUM2
# PHOTOURL
# zoMLSNUM
