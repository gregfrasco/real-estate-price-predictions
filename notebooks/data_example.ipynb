# %%
from utils import get_data

# %%
df = get_data('../data')
df.head()
# Out:
#        MLSNUM STATUS LISTPRICE SOLDPRICE   LISTDATE SOLDDATE  EXPIREDDATE  \
# 0  72115048.0    ACT    230000       NaN   2/1/2017      NaN          NaN
# 1  72279074.0    ACT    295500       NaN   2/7/2018      NaN          NaN
# 2  72283298.0    NEW    299000       NaN  2/19/2018      NaN          NaN
# 3  72226474.0    ACT    349000       NaN  9/11/2017      NaN          NaN
# 4  72281946.0    ACT    350000       NaN  2/15/2018      NaN          NaN
#
#      DOM  DTO             ADDRESS  ... ELEMENTARYSCHOOL JUNIORHIGHSCHOOL  \
# 0  356.0  NaN         64 Tampa St  ...              NaN              NaN
# 1  105.0  NaN      45 Faunce Road  ...              NaN   Mildred School
# 2  112.0  NaN  1923 Hyde Park Ave  ...              NaN              NaN
# 3  162.0  NaN      21 Kennebec St  ...              NaN              NaN
# 4    5.0  NaN    102 Neponset Ave  ...              NaN              NaN
#
#    HIGHSCHOOL                                      OTHERFEATURES  PROPTYPE  \
# ...
